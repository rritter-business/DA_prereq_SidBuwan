# %%
print("Hello World!")

# %% [markdown]
# Hi there! My name is Sid Buwan and I'm excited to learn more about Data Analysis, but I love learning in general and want to expand my coding knowledge in other languages as well (eventually). I hope to pivot from my current position as a baker back into the world of computers! Outside of learning to program, I enjoy hiking and identifying native species of plants and animals. I also make art and am currently learning digital art programs alongside making physical art. I'm terribly sad to see this program go. I had planned on participating in as many cohorts as I could, but I'm thankful for having been a part of the last cohort at all and I've gained some valuable resources already! I hope that everyone involved in Code:You finds success in other ventures and stays in touch.
